# %% [markdown]
# # Dealing with Structured Data- Global Terrorism Database

# %% [markdown]
# ### Thanks to Samuel Capps (6980 2020 QTR 1) for identifying this dynamic

# %%
# Import libraries to aid your analysis
import pandas as pd #pandas places ones data in tables format
from bokeh.plotting import figure, output_notebook, show #builds interactive graphs for python
from bokeh.models import Range1d
import math #this is used in graphic section to use the irrational number pi
output_notebook() #Allows inline plotting for Juptyer notebook
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Let's look at the data

# %%
pwd
# Out:
# '/home/cyfir/mst688/applications'

# %%
# Datasheet was downbloaed form GTD and being read in form a local .csv file
GTD = pd.read_excel(r"/home/cyfir/mst688/globalterrorismdb_0919dist.xlsx") 
# had some issues with the data types, had to search online for example to read properly
GTD.head() # see the structure--default is first five rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
# Pandas library has a describe function to apply algorithms against the data...
# whether approriate or not
GTD.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.914640e+05  191464.000000  191464.000000  191464.000000
# mean   2.003486e+11    2003.420136       6.462510      15.507688
# std    1.334949e+09      13.349405       3.388515       8.807727
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991083e+11    1991.000000       4.000000       8.000000
# 50%    2.010031e+11    2010.000000       6.000000      15.000000
# 75%    2.015013e+11    2015.000000       9.000000      23.000000
# max    2.018123e+11    2018.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  191464.000000  191464.000000  191464.000000  186884.000000
# mean        0.047476     131.290446       7.205167      23.462121
# std         0.212656     112.058063       2.923811      18.405309
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       6.000000      11.274796
# 50%         0.000000      98.000000       7.000000      31.445840
# 75%         0.000000     160.000000      10.000000      34.621521
# max         1.000000    1004.000000      12.000000      74.633553
#
#            longitude    specificity  ...     ransomamt   ransomamtus  \
# count  186883.000000  191463.000000  ...  1.416000e+03  6.230000e+02
# mean       28.902126       1.458172  ...  3.057619e+06  5.227734e+05
# std        57.231040       0.991536  ...  2.951278e+07  6.730057e+06
# min      -176.176447       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%         7.052742       1.000000  ...  0.000000e+00  0.000000e+00
# 50%        43.471427       1.000000  ...  1.500000e+04  0.000000e+00
# 75%        68.783077       1.000000  ...  4.000000e+05  0.000000e+00
# max       179.366667       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  8.380000e+02    611.000000    12045.000000  11454.000000
# mean   6.961705e+05    217.004910        4.643005    -29.816309
# std    9.792528e+06   2796.042504        2.034429     65.183303
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2912.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  191464.000000  191464.000000  191464.000000  191464.000000
# mean       -4.521727      -4.439247       0.088951      -3.930582
# std         4.543713       4.639931       0.556741       4.689726
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
#Identifies the total number of rows
len(GTD)
# Out:
# 191464

# %%
#provides information about the dataframe
GTD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191464 entries, 0 to 191463
# Columns: 135 entries, eventid to related
# dtypes: datetime64[ns](1), float64(53), int64(24), object(57)
# memory usage: 197.2+ MB

# %%
#See the titles of the 135 columns
for col in GTD.columns:
    print(col)
# !!!! Look in the GTD_Codebook to get more information about each column !!!!
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# # Problem 1: Change the Country (do after going through the whole notebook)

# %%
# reduce the dataframe down to just the philippines
country = GTD[GTD["country_txt"]=="Thailand"] # store the information in an object called country
#you can change Philippines to any country in the dataset
country.head(10) #by putting in 10 I changed the default setting of 1st 5 rows to 1st 10 rows
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1684  197212280001   1972      12    28        NaN         0        NaT
# 2350  197404230001   1974       4    23        NaN         1 1975-03-20
# 4824  197706000003   1977       6     0        NaN         0        NaT
# 4932  197706240001   1977       6    24        NaN         0        NaT
# 5318  197709220006   1977       9    22        NaN         0        NaT
# 6674  197808300004   1978       8    30        NaN         0        NaT
# 6676  197808310001   1978       8    31        NaN         0        NaT
# 6803  197809300008   1978       9    30        NaN         0        NaT
# 6887  197810190001   1978      10    19        NaN         0        NaT
# 6888  197810190002   1978      10    19        NaN         0        NaT
#
#       country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 1684      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 2350      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 4824      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 4932      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 5318      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 6674      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 6676      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 6803      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 6887      205    Thailand       5  ...      NaN    NaN    NaN     NaN
# 6888      205    Thailand       5  ...      NaN    NaN    NaN     NaN
#
#                dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 1684               PGIS        1         1        1       1      NaN
# 2350               PGIS       -9        -9        1       1      NaN
# 4824               PGIS        0         0        0       0      NaN
# 4932               PGIS        0         0        0       0      NaN
# 5318  UMD Miscellaneous        0         0        0       0      NaN
# 6674               PGIS        1         1        0       1      NaN
# 6676               PGIS       -9        -9        0      -9      NaN
# 6803               PGIS       -9        -9        0      -9      NaN
# 6887               PGIS        0         0        0       0      NaN
# 6888               PGIS       -9        -9        0      -9      NaN
#
# [10 rows x 135 columns]

# %% [markdown]
# ### Let's deep dive in a country

# %%
attacks_by_group = {} #make an empty datastructure (dictionary) to fill

#This loop goes through each row and counts the number of entries by group
for index, row in country.iterrows(): 
    if row["gname"]  in attacks_by_group.keys():
        attacks_by_group[row["gname"]] += 1 #if group is in the dictionary add 1 attack
    else:
        attacks_by_group[row["gname"]] = 1 #add group name to dictionary if not in dictionary

attacks_by_group
# Out:
# {'Black September': 1,
#  'Unknown': 3105,
#  'Sanidila Secessionist Movement': 2,
#  'Pattani United Liberation Organization (PULO)': 48,
#  'Khmer Rouge': 2,
#  'Communists': 31,
#  'Communist Party of Thailand': 3,
#  'Thai Communists': 1,
#  'Muslims': 2,
#  'Khmer Serei Guerrillas': 1,
#  'Malaysian Communist Party': 1,
#  'Insurgents': 4,
#  'Movement of Islamic Action of Iraq': 1,
#  'Muslim extremists': 7,
#  'Hezbollah': 1,
#  'Soldiers of Truth': 1,
#  'Kachin Independence Army (KIA)': 1,
#  'National Revolutionary Front': 1,
#  'Muslim Separatists': 32,
#  'Karen Insurgents': 4,
#  'Muslim Militants': 3,
#  'Cambodian guerrillas': 1,
#  'Anti-Government Demonstrators': 1,
#  'Mon Insurgents': 1,
#  'Muslim Guerrillas': 1,
#  'Jihadi-inspired extremists': 1,
#  'Democratic Karen Buddhist Army (DKBA)': 18,
#  'Cambodian Gunmen': 1,
#  'Karen National Union': 5,
#  'Vigorous Burmese Student Warriors': 1,
#  "God's Army": 2,
#  'Iraqi extremists': 1,
#  'Free Vietnam Movement': 1,
#  'Barisan Revolusi Nasional (BRN)': 117,
#  'Mujahideen Islam Pattani': 4,
#  'Young Liberators of Pattani': 1,
#  'Thai Islamic Militants': 58,
#  'National Liberation Alliance of Sa Kaeo': 1,
#  'Bersatu': 1,
#  'Separatists': 356,
#  'Naxalites': 1,
#  'Runda Kumpulan Kecil (RKK)': 152,
#  'National United Front of Democracy Against Dictatorship (UDD)': 1,
#  'United Front for Democracy Against Dictatorship': 24,
#  'Islamist extremists': 1,
#  'Gunmen': 1,
#  'Militants': 1,
#  'Maoists': 1,
#  'Yakariya Bango Insurgent Group': 2,
#  'Pattani United Liberation Organization-MKP (PULO-MKP)': 1,
#  'Aba Cheali Group': 1,
#  'Ahmad Luebaesa Group': 1,
#  'Fatoni Warriors': 1,
#  'Anti-Government extremists': 20}

# %%
''' OH GOOD HEAVENS THIS DATA IS TERRIBLE. Almost 90% of attacks are attributed to "Separatists" or "Unknown".
    I'm going to purge the attacks attributed to a generic type of group - 3 of the 5 top actual groups are Islamists,
    so we can't even infer membership for e.g. "Muslim Separatists."
    '''

import re

blacklisted_groups = []
blacklisted_words = ['communists', 'separatists', 'rebels', 'unknown', 'militants', 'muslims', 'insurgents', 'extremists']
blacklisted_regex = re.compile(r''.join([word + '|' for word in blacklisted_words])[:-1], re.IGNORECASE)
attacks_by_group_cleaned = attacks_by_group.copy()
for group, attacks in attacks_by_group.items():
    matched = blacklisted_regex.search(group)
    if matched:
        blacklisted_groups.append(group)
        del attacks_by_group_cleaned[group]
print(blacklisted_groups)
# Out:
# ['Unknown', 'Communists', 'Thai Communists', 'Muslims', 'Insurgents', 'Muslim extremists', 'Muslim Separatists', 'Karen Insurgents', 'Muslim Militants', 'Mon Insurgents', 'Jihadi-inspired extremists', 'Iraqi extremists', 'Thai Islamic Militants', 'Separatists', 'Islamist extremists', 'Militants', 'Anti-Government extremists']

# %%
# Make X and Y axis for a bar chart plotting attacks
groups = list(attacks_by_group_cleaned.keys())
attacks = list(attacks_by_group_cleaned.values())

# %%
#Sort from smallest to largest
sorted_groups = sorted(groups, key=lambda x: attacks[groups.index(x)])[-5:]
sorted_attacks = sorted(attacks)[-5:]

# %% [markdown]
# # Problem 2: For any country only do plot the top 5 groups (Hint: Use list slicing e.g sorted_attacks[-10:])

# %%
sorted_groups
# Out:
# ['Democratic Karen Buddhist Army (DKBA)',
#  'United Front for Democracy Against Dictatorship',
#  'Pattani United Liberation Organization (PULO)',
#  'Barisan Revolusi Nasional (BRN)',
#  'Runda Kumpulan Kecil (RKK)']

# %%
# Uses the bokeh library to plot an interactive graph ---this is very basic view of its capability
# makes the figure
p = figure(x_range = sorted_groups, plot_width=800, plot_height=1200)
#Plots the data
p.vbar(x=sorted_groups, width=0.5, bottom=0,
       top= sorted_attacks, color="firebrick")

p.xaxis.major_label_orientation = math.pi/2  #Rotates the labels on the X axis

# %%
show(p)
# Out:
#   <div class="bk-root" id="2043416b-cf01-44d3-8b1b-f13a2176f841" data-root-id="1431"></div>

# %% [markdown]
# ## Now lets plot the attacks in a map

# %%
#Imports necessary aspects of Bokeh for plotting on a map
from bokeh.tile_providers import get_provider, Vendors
from pyproj import Transformer
tile_provider = get_provider('STAMEN_TERRAIN')

# %%
# Take the data reduced to a country and get the lat/long of the attacks and the name of the group
country_map = country[["latitude", 'longitude', 'gname']]

#see the data this time first 7 rows
country_map.head(7)
# Out:
#        latitude   longitude                                          gname
# 1684  13.785793  100.560852                                Black September
# 2350   6.869484  101.250483                                        Unknown
# 4824   7.013983  100.471242                 Sanidila Secessionist Movement
# 4932  13.785793  100.560852  Pattani United Liberation Organization (PULO)
# 5318   6.201532  101.251838  Pattani United Liberation Organization (PULO)
# 6674  13.678221  102.521239                                    Khmer Rouge
# 6676  17.742222  102.057222                                        Unknown

# %%
#create pyproj transformer to convert form lat/long to web mercator
transformer = Transformer.from_crs('epsg:4326','epsg:3857')

# %%
map_dict = {} # empty dictionary to track group attacks by lat long
nan_count = {} # some data doesn't have a lat/long so we need to know what we are losing


# Iterate through tables and associate group with lat/long
for idx, row in country_map.iterrows():    
    if row['gname'] in map_dict.keys(): 
        if math.isnan(row["latitude"]):
            #This counts no data
            if row['gname'] in nan_count.keys(): 
                nan_count[row['gname']] += 1 
            else: 
                nan_count[row['gname']] = 1
        else: 
            #This has to convert the lat/long to a mercator projection 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']].append([point[0],point[1]]) 
    #BOTH the if an else statement do the same thing but since it is a dictionary one needs to add the group name first
    else:  
        if math.isnan(row["latitude"]):
          nan_count[row['gname']] = 1
        else: 
            point = transformer.transform(row["latitude"],row["longitude"])
            map_dict[row['gname']] =[[point[0],point[1]]]
        
#This tells how many attacks we are losing
nan_count
# Out:
# {'Thai Communists': 1,
#  'Unknown': 20,
#  'Communists': 4,
#  'Pattani United Liberation Organization (PULO)': 1,
#  'Kachin Independence Army (KIA)': 1,
#  'Muslim Separatists': 1,
#  'Mon Insurgents': 1,
#  'Democratic Karen Buddhist Army (DKBA)': 3,
#  'Cambodian Gunmen': 1,
#  'Karen National Union': 1}

# %% [markdown]
# # Problem 3: Print the top 5 groups from the map_dict structure

# %%
#Given that I cleaned the attack data earlier, rather than reinvent the wheel here, I'm going to just use the results there to filter map_dict

map_top_5 = { group: map_dict[group] for group in sorted_groups }
map_top_5
# Out:
# {'Democratic Karen Buddhist Army (DKBA)': [[10972722.355115272,
#    1887937.6941504169],
#   [10972722.355115272, 1887937.6941504169],
#   [11200302.029661696, 1632182.1630777142],
#   [11200302.029661696, 1632182.1630777142],
#   [10972722.355115272, 1887937.6941504169],
#   [10972722.355115272, 1887937.6941504169],
#   [11200302.029661696, 1632182.1630777142],
#   [10974362.313853638, 1888666.7128225463],
#   [10934418.876806177, 1947258.732654318],
#   [10972722.355115272, 1887937.6941504169],
#   [10972722.355115272, 1887937.6941504169],
#   [10972722.355115272, 1887937.6941504169],
#   [10972722.355115272, 1887937.6941504169],
#   [10974362.313853638, 1888666.7128225463],
#   [10997495.617235389, 1861658.0549081892]],
#  'United Front for Democracy Against Dictatorship': [[11316541.50798956,
#    1542504.0905542395],
#   [11269365.087027807, 712794.8523040204],
#   [11249945.624497902, 723651.5194084648],
#   [11270628.117970347, 729218.9008925497],
#   [11274481.99874161, 729744.0716019531],
#   [11274481.99874161, 729744.0716019531],
#   [11249932.377478497, 723757.6183138294],
#   [11270466.259430734, 732107.5688866382],
#   [11264377.194603832, 687361.0673725664],
#   [11332481.56851523, 695430.8228022363],
#   [11333371.12256616, 694060.7408752596],
#   [11332817.753377426, 695180.4319260578],
#   [11214334.964671096, 771040.4117944667],
#   [11272650.236520607, 698843.7928832894],
#   [11265702.119183255, 733473.071171426],
#   [11286545.246680915, 724462.8954106148],
#   [11127239.040352402, 1410462.4962878828],
#   [11127239.040352402, 1410462.4962878828],
#   [11127239.040352402, 1410462.4962878828],
#   [10942277.921536691, 881996.4181474422],
#   [11056826.011521444, 1021426.9910294077],
#   [11056826.011521444, 1021426.9910294077],
#   [10937379.418663824, 967172.4105674789],
#   [11088756.448982622, 843871.125035364],
#   [11002008.286753166, 897566.6901345314],
#   [10942277.921536691, 881996.4181474422],
#   [10937279.342441602, 967174.0995945408],
#   [10937279.342441602, 967174.0995945408],
#   [11127496.077056644, 942093.7760626656],
#   [10946871.409004785, 887985.4938881594],
#   [11127239.040352402, 1410462.4962878828],
#   [10967779.658404559, 944005.0177238256],
#   [11254027.932864273, 750898.343087009],
#   [11363716.147839462, 695736.8699876355],
#   [11234163.74896865, 757605.1006027957],
#   [11270110.70497714, 718277.1474497769],
#   [11265457.216303509, 733493.1292665219],
#   [11324567.086678302, 669471.259313365],
#   [11274515.839866811, 716872.0210708899],
#   [11274516.84174223, 716858.8023155673],
#   [11267087.490246177, 695284.12676587],
#   [11274426.784274178, 730231.7105178863],
#   [11276440.999140592, 696262.1819209843]]}

# %% [markdown]
# # Problem 4: Change the map to show a new country.
# ## You can get the lat/long for different places here : https://www.latlong.net/

# %%
pts = [(4.91,106.24), (21.00,97.29)]
bbox = []
for pt in transformer.itransform(pts): 
    bbox.append(pt)

# %%
  
coordinates_top_5 = {}
dot_colors = ['firebrick', 'darkmagenta', 'lightskyblue', 'cyan', 'mediumseagreen']
for group_color, group in enumerate(map_top_5):
    coordinates_top_5[group] = {
        'x': [],
        'y': [],
        'color': dot_colors[group_color]
    }
    for pt in map_top_5[group]:
        coordinates_top_5[group]['x'].append(pt[0])
        coordinates_top_5[group]['y'].append(pt[1])

# %%
#Plots the bounding box
p = figure(x_range=(bbox[0][0], bbox[1][0]),y_range=(bbox[0][1], bbox[1][1]),x_axis_type="mercator", y_axis_type="mercator")
#add the map form the Bokeh map vendor in this case Stamen_Terrain --- see documentation
p.add_tile(tile_provider)
# Places a circle for each converted lat/long attack 
for group_name, group in coordinates_top_5.items():
    p.circle(x = group['x'], y = group['y'], color= group['color'])

#shows the plot
show(p)
# Out:
#   <div class="bk-root" id="96544b2b-fbf7-44f5-a45c-0bb563869da6" data-root-id="1778"></div>
